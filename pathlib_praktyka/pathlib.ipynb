# %%
from pathlib import Path

# %%
folders = [
    'project',
    'project/data_raw/raw.csv',
    'project/data_processed/processed.csv',
    'project/charts',
    'project/client/emails'
]

# %%
for folder in folders:
    p = Path.cwd() / folder
    
    if p.suffix:
        p.parent.mkdir(parents=True)
        p.touch()

    else:
        p.mkdir(parents=True)

# %%
p = Path.cwd() / 'data.csv'

# %%
p
# Out:
# WindowsPath('c:/Users/Ja/Desktop/edukacja/pathlib_praktyka/data.csv')

# %%
p.parent.parent
# Out:
# WindowsPath('c:/Users/Ja/Desktop/edukacja')

# %%
p.home()
# Out:
# WindowsPath('C:/Users/Ja')

# %%
p = Path('na_testa.txt')
p
# Out:
# WindowsPath('na_testa.txt')

# %%
p = p.resolve()

# %%
p
# Out:
# WindowsPath('C:/Users/Ja/Desktop/edukacja/pathlib_praktyka/na_testa.txt')

# %%
p.rename(p.parent / 'testa.txt')
# Out:
# WindowsPath('C:/Users/Ja/Desktop/edukacja/pathlib_praktyka/testa.txt')

# %%
p.parts
# Out:
# ('C:\\',
#  'Users',
#  'Ja',
#  'Desktop',
#  'edukacja',
#  'pathlib_praktyka',
#  'na_testa.txt')
