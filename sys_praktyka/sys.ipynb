# %%
import sys

# %%
args = sys.argv
print(args)
# Out:
# ['d:\\Users\\Ja\\anaconda3\\Lib\\site-packages\\ipykernel_launcher.py', '--f=c:\\Users\\Ja\\AppData\\Roaming\\jupyter\\runtime\\kernel-v3edb24571301aad9d7a838290ae3b7e4030daf331.json']
