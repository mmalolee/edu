# %%
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\malol\\Desktop\\projekty_edukacja\\edukacja\\os_praktyka'

# %%
os.chdir('c:\\Users\\malol\\Desktop\\projekty_edukacja\\edukacja\\os_praktyka')

# %%
os.getcwd()
# Out:
# 'c:\\Users\\malol\\Desktop\\projekty_edukacja\\edukacja\\os_praktyka'

# %%
os.listdir()
# Out:
# ['app.ipynb', 'app.py']

# %%
os.makedirs('OS-Demo-2\\Sub-Dir-1')

# %%
os.listdir()
# Out:
# ['app.ipynb', 'app.py', 'OS-Demo-2']
