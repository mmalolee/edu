# %%
import argparse
        
parser = argparse.ArgumentParser()

# %%
# Out:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 parser.add_argument('--epochs', type=int)
#       2 parser.add_argument('-lr', type=float)
#
# File d:\Users\Ja\anaconda3\Lib\argparse.py:1489, in _ActionsContainer.add_argument(self, *args, **kwargs)
#    1486     except TypeError:
#    1487         raise ValueError("length of metavar tuple does not match nargs")
# -> 1489 return self._add_action(action)
#
# File d:\Users\Ja\anaconda3\Lib\argparse.py:1878, in ArgumentParser._add_action(self, action)
#    1876 def _add_action(self, action):
#    1877     if action.option_strings:
# -> 1878         self._optionals._add_action(action)
#    1879     else:
#    1880         self._positionals._add_action(action)
#
# File d:\Users\Ja\anaconda3\Lib\argparse.py:1696, in _ArgumentGroup._add_action(self, action)
#    1695 def _add_action(self, action):
# ...
